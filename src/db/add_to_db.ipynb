# %%
import os
if  "Kuran-I_Kerim_app/src/db" in os.getcwd():
    os.chdir("../../")

# %%
# !ls
# Out:
# data		Kuran.db  main.py    requirements.txt  test
# HayratKuran.db	LICENSE   README.md  src	       translations

# %%
if os.path.exists("Kuran.db"):
    os.remove("Kuran.db")

# %%
import pandas as pd
from db_manager import Db_manager
df=pd.read_excel("data/doc/surah.ods")

db_m=Db_manager(dbpath="Kuran.db")
db_m.generate_table()

# %%
for i in range(len(df["isim"])):
    db_m.add_surah(df["isim"][i],(int)(df["ayet_s"][i]),(int)(df["nuzul"][i]))
db_m.end_process()

# %%
lst:str=[]

#* Rebource -> https://kuran.diyanet.gov.tr/Yayinlar
with open("data/doc/Kuran.txt","r") as f:
    lst=f.readlines()
    
#? filter data
lst.remove("﷽\n")



with open("data/doc/cikti.txt","w") as f:
    f.writelines(lst)

# %% [markdown]
# ## add to database

# %%
sure_id=0
sayfa=0
for i in lst:
    if "﷍	﴿" in i: #? sure isimleri
        sure_id+=1
        db_m.add_ayat(-1,i,sure_id,0,sayfa+1)
        #print(-1,i,sure_id,0)
        ayet_id=1
    elif "﴾" in i:
        sayfa+=1
        ayetler=i.split("﴾")
        ayetler.pop()
        for a in ayetler:
            db_m.add_ayat(ayet_id,a+"﴾",sure_id,0,sayfa)
            #print(ayet_id,a+"﴾",sure_id,0)
            ayet_id+=1
db_m.end_process()

# %%
imams = {
    "10": {
        "subfolder": "Abu_Bakr_Ash-Shaatree_64kbps",
        "name": "Abu Bakr Ash-Shaatree",
        "bitrate": "64kbps"
    },
    "11": {
        "subfolder": "Abu_Bakr_Ash-Shaatree_128kbps",
        "name": "Abu Bakr Ash-Shaatree",
        "bitrate": "128kbps"
    },
    "7": {
        "subfolder": "Abdurrahmaan_As-Sudais_64kbps",
        "name": "Abdurrahmaan As-Sudais",
        "bitrate": "64kbps"
    },
    "8": {
        "subfolder": "Abdurrahmaan_As-Sudais_192kbps",
        "name": "Abdurrahmaan As-Sudais",
        "bitrate": "192kbps"
    },
    "42": {
        "subfolder": "Mustafa_Ismail_48kbps",
        "name": "Mustafa Ismail",
        "bitrate": "48kbps"
    },
    "68": {
        "subfolder": "Nasser_Alqatami_128kbps",
        "name": "Nasser_Alqatami",
        "bitrate": "128kbps"
    },
    "1": {
        "subfolder": "Abdul_Basit_Murattal_64kbps",
        "name": "Abdul Basit Murattal",
        "bitrate": "64kbps"
    },
    "2": {
        "subfolder": "Abdul_Basit_Murattal_192kbps",
        "name": "Abdul Basit Murattal",
        "bitrate": "192kbps"
    },
    "5": {
        "subfolder": "Abdullah_Basfar_64kbps",
        "name": "Abdullah Basfar",
        "bitrate": "64kbps"
    },
    "6": {
        "subfolder": "Abdullah_Basfar_192kbps",
        "name": "Abdullah Basfar",
        "bitrate": "192kbps"
    },

    "9": {
        "subfolder": "AbdulSamad_64kbps_QuranExplorer.Com",
        "name": "AbdulSamad QuranExplorer.Com",
        "bitrate": "64kbps"
    },
    "12": {
        "subfolder": "Ahmed_ibn_Ali_al-Ajamy_64kbps_QuranExplorer.Com",
        "name": "Ahmed ibn Ali al-Ajamy QuranExplorer.Com",
        "bitrate": "64kbps"
    },
    "13": {
        "subfolder": "Ahmed_ibn_Ali_al-Ajamy_128kbps_ketaballah.net",
        "name": "Ahmed ibn Ali al-Ajamy KetabAllah.Net",
        "bitrate": "128kbps"
    },
    "17": {
        "subfolder": "Hani_Rifai_64kbps",
        "name": "Hani Rifai",
        "bitrate": "64kbps"
    },
    "18": {
        "subfolder": "Hani_Rifai_192kbps",
        "name": "Hani Rifai",
        "bitrate": "192kbps"
    },
    "19": {
        "subfolder": "Husary_64kbps",
        "name": "Husary",
        "bitrate": "64kbps"
    },
    "20": {
        "subfolder": "Husary_128kbps",
        "name": "Husary",
        "bitrate": "128kbps"
    },
    "21": {
        "subfolder": "Husary_Mujawwad_64kbps",
        "name": "Husary Mujawwad",
        "bitrate": "64kbps"
    },
    "22": {
        "subfolder": "Husary_128kbps_Mujawwad",
        "name": "Husary Mujawwad",
        "bitrate": "128kbps"
    },
    "24": {
        "subfolder": "Hudhaify_64kbps",
        "name": "Hudhaify",
        "bitrate": "64kbps"
    },
    "25": {
        "subfolder": "Hudhaify_128kbps",
        "name": "Hudhaify",
        "bitrate": "128kbps"
    },
    "27": {
        "subfolder": "Ibrahim_Akhdar_64kbps",
        "name": "Ibrahim Akhdar",
        "bitrate": "64kbps"
    },
    "28": {
        "subfolder": "Maher_AlMuaiqly_64kbps",
        "name": "Maher Al Muaiqly",
        "bitrate": "64kbps"
    },
    "29": {
        "subfolder": "MaherAlMuaiqly128kbps",
        "name": "Maher Al Muaiqly",
        "bitrate": "128kbps"
    },
    "32": {
        "subfolder": "Minshawy_Mujawwad_64kbps",
        "name": "Minshawy Mujawwad",
        "bitrate": "64kbps"
    },
    "33": {
        "subfolder": "Minshawy_Mujawwad_192kbps",
        "name": "Minshawy Mujawwad",
        "bitrate": "192kbps"
    },
    "35": {
        "subfolder": "Mohammad_al_Tablaway_64kbps",
        "name": "Mohammad al Tablaway",
        "bitrate": "64kbps"
    },
    "36": {
        "subfolder": "Mohammad_al_Tablaway_128kbps",
        "name": "Mohammad al Tablaway",
        "bitrate": "128kbps"
    },
    "37": {
        "subfolder": "Muhammad_Ayyoub_128kbps",
        "name": "Muhammad Ayyoub",
        "bitrate": "128kbps"
    },
    "38": {
        "subfolder": "Muhammad_Ayyoub_64kbps",
        "name": "Muhammad Ayyoub",
        "bitrate": "64kbps"
    },
    "40": {
        "subfolder": "Muhammad_Jibreel_64kbps",
        "name": "Muhammad Jibreel",
        "bitrate": "64kbps"
    },
    "41": {
        "subfolder": "Muhammad_Jibreel_128kbps",
        "name": "Muhammad Jibreel",
        "bitrate": "128kbps"
    },

    "43": {
        "subfolder": "Saood_ash-Shuraym_64kbps",
        "name": "Saood bin Ibraaheem Ash-Shuraym",
        "bitrate": "64kbps"
    },
    "44": {
        "subfolder": "Saood_ash-Shuraym_128kbps",
        "name": "Saood bin Ibraaheem Ash-Shuraym",
        "bitrate": "128kbps"
    },
    "51": {
        "subfolder": "Salaah_AbdulRahman_Bukhatir_128kbps",
        "name": "Salaah AbdulRahman Bukhatir",
        "bitrate": "128kbps"
    },
    "52": {
        "subfolder": "Muhsin_Al_Qasim_192kbps",
        "name": "Muhsin Al Qasim",
        "bitrate": "192kbps"
    },
    "53": {
        "subfolder": "Abdullaah_3awwaad_Al-Juhaynee_128kbps",
        "name": "Abdullaah 3awwaad Al-Juhaynee",
        "bitrate": "128kbps"
    },
    "54": {
        "subfolder": "Salah_Al_Budair_128kbps",
        "name": "Salah Al Budair",
        "bitrate": "128kbps"
    },
    "55": {
        "subfolder": "Abdullah_Matroud_128kbps",
        "name": "Abdullah Matroud",
        "bitrate": "128kbps"
    },
    "56": {
        "subfolder": "Ahmed_Neana_128kbps",
        "name": "Ahmed Neana",
        "bitrate": "128kbps"
    },
    "57": {
        "subfolder": "Muhammad_AbdulKareem_128kbps",
        "name": "Muhammad AbdulKareem",
        "bitrate": "128kbps"
    },
    "58": {
        "subfolder": "khalefa_al_tunaiji_64kbps",
        "name": "Khalefa Al-Tunaiji",
        "bitrate": "64kbps"
    },
    "64": {
        "subfolder": "Karim_Mansoori_40kbps",
        "name": "Karim Mansoori (Iran)",
        "bitrate": "40kbps"
    },
    "65": {
        "subfolder": "Husary_Muallim_128kbps",
        "name": "Husary (Muallim)",
        "bitrate": "128kbps"
    },
    "66": {
        "subfolder": "Khaalid_Abdullaah_al-Qahtaanee_192kbps",
        "name": "Khalid Abdullah al-Qahtanee",
        "bitrate": "192kbps"
    },
    "67": {
        "subfolder": "Yasser_Ad-Dussary_128kbps",
        "name": "Yasser_Ad-Dussary",
        "bitrate": "128kbps"
    },

    "69": {
        "subfolder": "Ali_Hajjaj_AlSuesy_128kbps",
        "name": "Ali_Hajjaj_AlSuesy",
        "bitrate": "128kbps"
    },
    "70": {
        "subfolder": "Sahl_Yassin_128kbps",
        "name": "Sahl_Yassin",
        "bitrate": "128kbps"
    },
    "71": {
        "subfolder": "ahmed_ibn_ali_al_ajamy_128kbps",
        "name": "Ahmed Ibn Ali Al Ajamy",
        "bitrate": "128kbps"
    },
    "73": {
        "subfolder": "aziz_alili_128kbps",
        "name": "Aziz Alili",
        "bitrate": "128kbps"
    },
    "74": {
        "subfolder": "Yaser_Salamah_128kbps",
        "name": "Yaser Salamah",
        "bitrate": "128kbps"
    },
    "75": {
        "subfolder": "Akram_AlAlaqimy_128kbps",
        "name": "Akram Al Alaqimy",
        "bitrate": "128kbps"
    },
    "76": {
        "subfolder": "Ali_Jaber_64kbps",
        "name": "Ali Jaber",
        "bitrate": "64kbps"
    },
    "77": {
        "subfolder": "Fares_Abbad_64kbps",
        "name": "Fares Abbad",
        "bitrate": "64kbps"
    },
    "79": {
        "subfolder": "Ayman_Sowaid_64kbps",
        "name": "Ayman Sowaid",
        "bitrate": "64kbps"
    }}

# %%
deneme=imams.values()
for i in deneme:
    db_m.add_imam(i["name"]+f"-{i['bitrate']}",i["subfolder"])
    #print(i)
    #print(i["name"]+f"-{i['bitrate']}",i["subfolder"])

# %%
ie=571
#* https://everyayah.com/data/Abdul_Basit_Murattal_64kbps/001002.mp3

# %%
aa=(1,)
bb=(4,56)
aa+bb
# Out:
# (1, 4, 56)

# %%
import os
if  "Kuran-I_Kerim_app/src/db" in os.getcwd():
    os.chdir("../../")

# %%
from src.db.db_external_pro import Db_Ex_pro
db_b = Db_Ex_pro("HayratKuran.db")
db_k = Db_Ex_pro("Kuran.db")
page_l = db_b.get_element("Ayet", "SureNu,AyetNu,SayfaNu")
for e in page_l:
    db_k.update_element(tablo_name="Ayat", up_col="page", where_col= ["surah_id","ayat_no"], new_data= e[2], where_data=e[0:2])
    #print(e)
ayet=db_k.get_element("Ayat", "page")
print(ayet)
db_k.end_process()
db_b.end_process()
# Out:
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 1)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 2)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 3)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 4)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 5)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 6)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (0, 1, 7)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (1, 2, 1)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (1, 2, 2)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (1, 2, 3)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (1, 2, 4)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (1, 2, 5)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 6)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 7)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 8)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 9)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 10)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 11)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 12)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 13)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 14)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 15)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (2, 2, 16)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 17)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 18)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 19)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 20)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 21)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 22)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 23)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (3, 2, 24)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (4, 2, 25)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (4, 2, 26)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (4, 2, 27)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (4, 2, 28)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (4, 2, 29)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 30)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 31)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 32)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 33)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 34)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 35)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 36)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (5, 2, 37)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 38)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 39)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 40)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 41)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 42)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 43)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 44)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 45)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 46)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 47)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (6, 2, 48)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 49)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 50)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 51)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 52)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 53)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 54)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 55)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 56)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (7, 2, 57)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (8, 2, 58)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (8, 2, 59)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (8, 2, 60)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (8, 2, 61)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 62)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 63)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 64)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 65)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 66)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 67)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 68)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (9, 2, 69)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 70)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 71)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 72)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 73)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 74)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 75)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (10, 2, 76)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 77)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 78)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 79)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 80)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 81)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 82)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (11, 2, 83)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (12, 2, 84)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (12, 2, 85)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (12, 2, 86)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (12, 2, 87)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (12, 2, 88)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (13, 2, 89)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (13, 2, 90)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (13, 2, 91)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (13, 2, 92)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (13, 2, 93)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 94)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 95)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 96)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 97)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 98)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 99)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 100)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (14, 2, 101)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (15, 2, 102)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (15, 2, 103)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (15, 2, 104)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (15, 2, 105)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 106)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 107)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 108)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 109)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 110)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 111)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (16, 2, 112)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 113)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 114)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 115)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 116)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 117)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 118)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (17, 2, 119)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 120)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 121)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 122)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 123)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 124)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 125)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (18, 2, 126)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 127)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 128)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 129)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 130)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 131)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 132)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 133)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (19, 2, 134)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 135)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 136)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 137)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 138)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 139)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 140)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (20, 2, 141)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (21, 2, 142)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (21, 2, 143)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (21, 2, 144)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (21, 2, 145)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (22, 2, 146)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (22, 2, 147)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (22, 2, 148)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (22, 2, 149)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ? (22, 2, 150)
# UPDATE Ayat SET page = ? WHERE surah_id = ?AND ayat_no = ?